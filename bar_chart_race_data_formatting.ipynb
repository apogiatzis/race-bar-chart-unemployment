# %%
import pandas as pd
import re

# %%
data_url = "https://raw.githubusercontent.com/apogiatzis/race-bar-chart-unemployment/master/data/unemployment_per_economic_activity_monthly.csv"
df = pd.read_csv(data_url)
df.head()
# Out:
#   NACE 2 CODE Activity Code  \
# 0           A             1
# 1           B             2
# 2           C             3
# 3           D             4
# 4           E             5
#
#                                    Economic Activity  Year       Month  \
# 0                      Γεωργία, δασοκομία και αλιεία  2013  Ιανουάριος
# 1                               Ορυχεία και λατομεία  2013  Ιανουάριος
# 2                                         Μεταποίηση  2013  Ιανουάριος
# 3  Παροχή ηλεκτρικού ρεύματος, φυσικού αερίου, ατ...  2013  Ιανουάριος
# 4  Παροχή νερού, επεξεργασία λυμάτων, διαχείριση ...  2013  Ιανουάριος
#
#    Anastoles-Metapoiisi  Anastoles-Touristiki  Termatismoi-Touristiki  \
# 0                     0                     0                       0
# 1                     0                     0                       0
# 2                   141                     0                       0
# 3                     0                     0                       0
# 4                     0                     0                       0
#
#    Termatismoi-Alloi  Total
# 0                159    159
# 1                 62     62
# 2               2690   2831
# 3                 15     15
# 4                 31     31

# %%
## Month Translation table 
## The prefix is to maintain sorted columns
month_gr2en = {'Ιανουάριος': '_01 Jan', 'Φεβρουάριος': '_02 Feb', 'Μάρτιος': '_03 Mar',
               'Απρίλιος': '_04 Apr', 'Μάιος':'_05 May', 'Ιούνιος':'_06 Jun',
               'Ιούλιος': '_07 Jul', 'Αύγουστος':'_08 Aug', 'Σεπτέμβριος': '_09 Sep',
               'Οκτώβριος':'_10 Oct', 'Νοέμβριος':'_11 Nov',
               'Δεκέμβριος': '_12 Dec'}

# %%
## Group by Economic Activity just to get the unique EA categories.
## Could be done with .unique() method but this makes sure there are
## not dangling categories.
df_grouped = df.groupby('Economic Activity')

## Group by Year and Month to group up the data 
## of the new dataframe per column.
df_year_groups = df.groupby(['Year', 'Month'])

# %%
EA_TOTAL_COLUMNS = [2, 9] # Indices of Economic Activity and Total columns

formatted_df = pd.DataFrame(index=df_grouped.groups.keys()) # Empty DF, only indices

## Create a new dataframe with the total unemployment per economic activity
## and concat with the previous one
for k,v in df_year_groups.groups.items():
  column_label = str(k[0]) + ' ' + month_gr2en[k[1]]
  aggregated = df.iloc[v, EA_TOTAL_COLUMNS].set_index('Economic Activity')
  aggregated.rename(columns={'Total': column_label}, inplace=True)
  formatted_df = pd.concat([formatted_df, aggregated], axis=1, join_axes=[formatted_df.index])  

## Because of groupby, columns are not sorted. Sort month colums
sorted_columns = list(formatted_df.columns.sort_values())

## Add category field + the sorted columns
formatted_df['category'] = range(len(df_grouped.groups.keys()))
formatted_df = formatted_df[['category'] + sorted_columns]

## Remove the prefix used for ordering from the month oclumns
formatted_df.columns = list(map(lambda col: re.sub(r"_[0-9]*[ \t]+","", col),
                               formatted_df.columns))

## Set Index
formatted_df.index.name = 'Economic Activity'

## Remove Unwanted Eaconomic Activity categories
formatted_df = formatted_df.drop(['Μη δηλωμένη οικονομική δραστηριότητα', 'Σύνολο'])

## Save to csv
formatted_df.to_csv('data.csv', encoding='utf-8-sig')

formatted_df.head()
# Out:
#                                                     category  2013 Jan  \
# Economic Activity
# Άλλες δραστηριότητες παροχής υπηρεσιών                     0       512
# Γεωργία, δασοκομία και αλιεία                              1       159
# Δημόσια διοίκηση και άμυνα. Υποχρεωτική κοινωνι...         2      3140
# Διαχείριση ακίνητης περιουσίας                             3       202
# Διοικητικές και υποστηρικτικές δραστηριότητες              4       849
#
#                                                     2013 Feb  2013 Mar  \
# Economic Activity
# Άλλες δραστηριότητες παροχής υπηρεσιών                   515       512
# Γεωργία, δασοκομία και αλιεία                            159       159
# Δημόσια διοίκηση και άμυνα. Υποχρεωτική κοινωνι...      2775      2723
# Διαχείριση ακίνητης περιουσίας                           201       177
# Διοικητικές και υποστηρικτικές δραστηριότητες            827       820
#
#                                                     2013 Apr  2013 May  \
# Economic Activity
# Άλλες δραστηριότητες παροχής υπηρεσιών                   487       403
# Γεωργία, δασοκομία και αλιεία                            165       157
# Δημόσια διοίκηση και άμυνα. Υποχρεωτική κοινωνι...      2767      2652
# Διαχείριση ακίνητης περιουσίας                           179       177
# Διοικητικές και υποστηρικτικές δραστηριότητες            784       594
#
#                                                     2013 Jun  2013 Jul  \
# Economic Activity
# Άλλες δραστηριότητες παροχής υπηρεσιών                   471       571
# Γεωργία, δασοκομία και αλιεία                            156       162
# Δημόσια διοίκηση και άμυνα. Υποχρεωτική κοινωνι...      2651      2401
# Διαχείριση ακίνητης περιουσίας                           163       166
# Διοικητικές και υποστηρικτικές δραστηριότητες            545       514
#
#                                                     2013 Aug  2013 Sep  ...  \
# Economic Activity                                                       ...
# Άλλες δραστηριότητες παροχής υπηρεσιών                   623       599  ...
# Γεωργία, δασοκομία και αλιεία                            164       170  ...
# Δημόσια διοίκηση και άμυνα. Υποχρεωτική κοινωνι...      2188      2275  ...
# Διαχείριση ακίνητης περιουσίας                           172       168  ...
# Διοικητικές και υποστηρικτικές δραστηριότητες            478       472  ...
#
#                                                     2017 Mar  2017 Apr  \
# Economic Activity
# Άλλες δραστηριότητες παροχής υπηρεσιών                   434       355
# Γεωργία, δασοκομία και αλιεία                             99        95
# Δημόσια διοίκηση και άμυνα. Υποχρεωτική κοινωνι...      1769      1549
# Διαχείριση ακίνητης περιουσίας                           283       253
# Διοικητικές και υποστηρικτικές δραστηριότητες            686       530
#
#                                                     2017 May  2017 Jun  \
# Economic Activity
# Άλλες δραστηριότητες παροχής υπηρεσιών                   287       297
# Γεωργία, δασοκομία και αλιεία                            111       105
# Δημόσια διοίκηση και άμυνα. Υποχρεωτική κοινωνι...       685      1058
# Διαχείριση ακίνητης περιουσίας                           231       186
# Διοικητικές και υποστηρικτικές δραστηριότητες            423       296
#
#                                                     2017 Jul  2017 Aug  \
# Economic Activity
# Άλλες δραστηριότητες παροχής υπηρεσιών                   389       391
# Γεωργία, δασοκομία και αλιεία                            107        99
# Δημόσια διοίκηση και άμυνα. Υποχρεωτική κοινωνι...      1677      1739
# Διαχείριση ακίνητης περιουσίας                           170        95
# Διοικητικές και υποστηρικτικές δραστηριότητες            297       290
#
#                                                     2017 Sep  2017 Oct  \
# Economic Activity
# Άλλες δραστηριότητες παροχής υπηρεσιών                   314       247
# Γεωργία, δασοκομία και αλιεία                             96        96
# Δημόσια διοίκηση και άμυνα. Υποχρεωτική κοινωνι...      1188       568
# Διαχείριση ακίνητης περιουσίας                            84        91
# Διοικητικές και υποστηρικτικές δραστηριότητες            264       290
#
#                                                     2017 Nov  2017 Dec
# Economic Activity
# Άλλες δραστηριότητες παροχής υπηρεσιών                   360       429
# Γεωργία, δασοκομία και αλιεία                             70        68
# Δημόσια διοίκηση και άμυνα. Υποχρεωτική κοινωνι...       778      1759
# Διαχείριση ακίνητης περιουσίας                           136       159
# Διοικητικές και υποστηρικτικές δραστηριότητες            666       780
#
# [5 rows x 61 columns]
